# %% [markdown]
# <a href="https://colab.research.google.com/github/Nabarundutta/Machine-Learning/blob/main/polynomialRegg1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline

# %%
X = 6*np.random.rand(200,1)-3
y = 0.5*X**2+X+2+np.random.randn(200,1)

# %%
import matplotlib.pyplot as plt
plt.plot(X,y,'b.')
plt.xlabel("X")
plt.ylabel('y')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5902908819224209

# %%
plt.plot(X_test,y_pred,'r.')
plt.plot(X,y,'b.')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Polynomial Regression needs degree 2

# %%
poly = PolynomialFeatures(degree=2)
X_train_trans = poly.fit_transform(X_train)
X_test_trans = poly.transform(X_test)

# %%
print(X_train[0])
print(X_train_trans[0])
# Out:
# [-2.2573835]
# [ 1.         -2.2573835   5.09578027]

# %%
lr = LinearRegression()
lr.fit(X_train_trans,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_trans)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8591877955287617

# %%
plt.plot(X_test,y_pred,'r.')
plt.plot(X,y,'b.')
plt.xlabel('X')
plt.ylabel('y')
plt.show()
